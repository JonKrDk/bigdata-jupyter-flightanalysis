# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
with open('flights.json','r') as f:
    data = json.loads(f.read())

# %%
df = pd.json_normalize(data, record_path =['response'])

# %%
df
# Out:
#           hex reg_number flag        lat        lng    alt  dir  speed  \
# 0      152007   RA-73735   RU  56.834000  53.212456  11574  271    755
# 1      152022   RA-73762   RU  48.030991  49.615425  10972  359    857
# 2      152035   RA-73781   RU  57.808243  39.534576  10980  251    811
# 3      152042   RA-73794   RU  51.700123  51.005325  10957  331    794
# 4      152050   RA-73808   RU  56.044846  50.498917  11887   92    870
# ...       ...        ...  ...        ...        ...    ...  ...    ...
# 12181  C06A87     C-GOIW   CA  45.466000 -41.837597   9753  279    788
# 12182  C06A8D     C-GOJC   CA  58.883484 -27.654797   9753  264    759
# 12183  E0658E     LV-FVN   AR -49.918617 -68.038742  11582  204    814
# 12184  E07542     LV-GUB   AR -53.232944 -67.159622  11582  201    822
# 12185  E80331     CC-AZN   CL -44.835854 -71.813606  10675  175    788
#
#        v_speed squawk  ... flight_iata dep_icao dep_iata arr_icao arr_iata  \
# 0          0.0   5511  ...      SU1405     USSS      SVX     UUEE      SVO
# 1          0.0   2426  ...      SU1301     URMM      MRV     UUEE      SVO
# 2         -0.3   5554  ...      SU1769     USPP      PEE     UUEE      SVO
# 3          0.0   2512  ...      U68428     UTDD      DYU     UUBW      ZIA
# 4          0.0   2141  ...       U6299     UUDD      DME     USSS      SVX
# ...        ...    ...  ...         ...      ...      ...      ...      ...
# 12181      NaN   2000  ...       TS233     LPFR      FAO     CYYZ      YYZ
# 12182      NaN   4071  ...       TS629     LFMN      NCE     CYUL      YUL
# 12183      NaN   1774  ...      AR1802     SABE      AEP     SAWG      RGL
# 12184      NaN   1723  ...      AR1890     SABE      AEP     SAWH      USH
# 12185      NaN   2216  ...         H21     SCEL      SCL     SCCI      PUQ
#
#       airline_icao airline_iata aircraft_icao     updated    status
# 0              AFL           SU          A20N  1664987866  en-route
# 1              AFL           SU          A320  1664987822  en-route
# 2              AFL           SU          A320  1664988084  en-route
# 3              SVR           U6          A321  1664988092  en-route
# 4              SVR           U6          A320  1664988092  en-route
# ...            ...          ...           ...         ...       ...
# 12181          TSC           TS          A21N  1664988067  en-route
# 12182          TSC           TS          A21N  1664988067  en-route
# 12183          ARG           AR          B738  1664987227  en-route
# 12184          ARG           AR          B738  1664987347  en-route
# 12185          SKU           H2          A20N  1664988067  en-route
#
# [12186 rows x 22 columns]

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.scatterplot(data=df, x='alt', y='speed', hue='v_speed', palette='plasma')
# Out:
# <AxesSubplot:xlabel='alt', ylabel='speed'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.scatterplot(data=df, x='v_speed', y='speed', hue='alt', palette='hsv')
# Out:
# <AxesSubplot:xlabel='v_speed', ylabel='speed'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.scatterplot(data=df, x='lng', y='lat', hue='speed')
# Out:
# <AxesSubplot:xlabel='lng', ylabel='lat'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.scatterplot(data=df, x='lng', y='lat', hue='alt', style='status')
# Out:
# <AxesSubplot:xlabel='lng', ylabel='lat'>

# %%
sns.displot(data=df, x='speed', bins=50, height=8, aspect=3, kde=True)
